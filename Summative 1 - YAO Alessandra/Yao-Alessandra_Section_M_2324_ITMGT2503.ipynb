# %% [markdown]
# # General Instructions
# Change the filenames to LastName-FirstName_Section_M-N_2324_ITMGT2503 <br>
# __Ex. GAW-Adriel_SectionM_2324_ITMGT2503__

# %% [markdown]
# # Question 1: Watch Your Words
# Your task is to count the number of times that each word was used in a movie script! Please be guided by the instructions below!

# %% [markdown]
# #### 1a

# %%
import json 
with open("output_dictionary_Q1.json","r") as file:
    mydata = json.load(file)
print (mydata)

len(mydata)
# Out:
# {'JOY': 585, 'NARRATES': 22, 'YOU': 273, 'EVER': 4, 'LOOK': 40, 'SOMEONE': 2, 'AND': 351, 'WONDER': 3, 'WHAT': 134, 'GOING': 35, 'INSIDE': 11, 'THEIR': 15, 'HEAD': 19, 'WELL': 40, 'KNOW': 45, 'RILEY': 326, 'FADES': 6, 'WHITE': 1, 'SPACE': 2, 'HOSPITAL': 1, 'ROOM': 34, 'MRS': 40, 'ANDERSEN': 77, 'ARE': 89, 'ADMIRING': 1, 'NEWBORN': 1, 'BABY': 2, 'WHO': 34, 'WAKES': 3, 'COOS': 3, 'HAPPILY': 4, 'ZOOM': 4, 'MIND': 13, 'EVERYTHING': 14, 'BLACK': 7, 'FROM': 45, 'OUT': 106, 'THE': 830, 'DARKNESS': 4, 'STEPS': 10, 'GLOWING': 3, 'FIGURE': 9, 'SHE': 188, 'COMES': 17, 'FORWARD': 9, 'SEES': 10, 'BLANK': 1, 'SCREEN': 29, 'ABOVE': 3, 'HER': 132, 'BELOW': 6, 'SINGLE': 3, 'BUTTON': 13, 'PRESSES': 3, 'TURNS': 24, 'YELLOW': 8, 'LIKE': 59, 'HEARD': 8, 'COOING': 1, 'BACK': 84, 'REAL': 4, 'WORLD': 5, 'SHOWING': 4, 'GIGGLES': 3, 'THERE': 77, 'WAS': 54, 'ANDERSENS': 6, 'FACES': 4, 'MATERIALIZE': 1, 'INTO': 62, 'VIEW': 5, 'HELLO': 7, 'AREN': 3, 'LITTLE': 5, 'BUNDLE': 2, 'DING': 5, 'ORB': 2, 'JUST': 69, 'HAPPENED': 7, 'FORMED': 2, 'BEHIND': 25, 'EXAMINES': 1, 'MEMORY': 112, 'PUTS': 12, 'PLACE': 16, 'ROLLS': 10, 'ACROSS': 11, 'RACK': 1, 'AROUND': 29, 'AREA': 1, 'MAKING': 7, 'LIGHTS': 6, 'COME': 30, 'REVEALING': 1, 'RED': 5, 'VIOLET': 1, 'GEARS': 1, 'HEADQUARTERS': 80, 'STARTING': 5, 'FORM': 2, 'ASTOUNDED': 2, 'AGAIN': 16, 'RESPONSE': 5, 'BEAMS': 3, 'AMAZING': 4, 'FOREVER': 5, 'KEEPS': 6, 'GIGGLING': 2, 'SMILES': 7, 'REPLY': 1, 'SUDDENLY': 10, 'STARTS': 9, 'CRYING': 10, 'WHICH': 20, 'CONFUSES': 1, 'FOR': 53, 'THIRTY': 1, 'THREE': 10, 'SECONDS': 1, 'NEXT': 9, 'DROOPY': 2, 'GLOOMY': 1, 'BLUE': 23, 'SADNESS': 274, 'WORKING': 11, 'C
ITS': 10, 'READS': 7, 'NEWSPAPER': 2, 'HEADLINE': 1, 'DOWN': 60, 'LIVIDLY': 1, 'WAIT': 34, 'DID': 31, 'SAY': 10, 'COULDN': 4, 'HIS': 27, 'BEGINS': 5, 'FLAME': 1, 'CARES': 1, 'DEEPLY': 1, 'ABOUT': 33, 'THINGS': 17, 'FAIR': 1, 'HOW': 30, 'PLAY': 20, 'OLD': 8, 'MAN': 6, 'SURE': 17, 'AFTER': 13, 'MANS': 1, 'LETTING': 2, 'FURIOUS': 1, 'YELL': 5, 'DOES': 9, 'THING': 8, 'HEAVY': 1, 'DRUMROLL': 1, 'BACKGROUND': 1, 'SCORE': 1, 'SCREAM': 5, 'ANGRY': 3, 'THROWING': 1, 'FIT': 3, 'WHEN': 23, 'INT ...
# 2489

# %%
# First, to help guide you, here is a list containing tuples. Run this block of code to initialize the list
list_of_tuples = [('A',59),('B',100),('C',20),('D',88),('E',25),('F',38)]

list_of_tuples
# Out:
# [('A', 59), ('B', 100), ('C', 20), ('D', 88), ('E', 25), ('F', 38)]

# %% [markdown]
# If we want to __sort this tuple according to the numerical value__, using the sort() without any other arguments will not suffice. But, diving a bit deeper into the sort() function, we can see that it can accept two parameters:
#
# - `key` which is what will be used as the basis for sorting
# - `reverse` which accepts a Boolean value to determine if the sorting will be ascending or descending

# %%
# execute this cell to see how the two arguments help us achieve the desired result

list_of_tuples.sort(key=lambda x: x[1], reverse=True)

print(list_of_tuples)
# Out:
# [('B', 100), ('D', 88), ('A', 59), ('F', 38), ('E', 25), ('C', 20)]

# %% [markdown]
# #### 1b

# %%
# To formally start this problem:
# Load the "script.json" file and store it in the `jsondata` variable. 
# The dictionary will contain the "line number" (starting from 0) as the key, 
# and the lines itself as the value

# %%
import json 
with open("script (1).json","r") as file:
    jsondata = json.load(file)
print (jsondata)
# Out:
# {'0': '<p><b>Joy:</b> <i>(narrates:)</i> Do you ever look at someone and wonder, "What is going on inside their head?" Well, I know. ...Well, I know Riley\'s head. \n</p>', '1': "<p><i>(Fades up in a white space; in a hospital room, Mr. and Mrs. Andersen are admiring their newborn baby Riley, who wakes up and coos happily. Zoom in on Riley's head.)</i>\n</p>", '2': "<p><i>(In Riley's mind, everything is black. From out of the darkness steps a glowing figure, Joy. She comes forward and sees a blank screen above her; below her is a single button. She presses it, and it turns yellow like her. Riley is heard cooing.)</i>\n</p>", '3': '<p><i>(Zoom back from Joy to the real world, showing the baby Riley as she coos and giggles happily.)</i>\n</p>', '4': '<p><b>Joy:</b> <i>(narrates:)</i> And there she was...\n</p>', '5': "<p><i>(On the screen, Mr. and Mrs. Andersens' faces materialize into view.)</i>\n</p>", '6': '<p><b>Mrs. Andersen:</b> Hello, Riley.\n</p>', '7': "<p><b>Mr. Andersen:</b> Oh, look at you. Aren't you a little bundle of joy?\n</p>", '8': '<p><i>(A ding is heard, and a glowing yellow orb of what just happened is formed from behind the screen. Joy examines it.)</i>\n</p>', '9': "<p><b>Memory Mr. Andersen:</b> Aren't you a little bundle of joy?\n</p>", '10': '<p><i>(She puts the memory back in place and it rolls across a rack around the area, making the lights come up and revealing a red-violet space of gears, as Headquarters is starting to form. Joy is astounded; she presses the button again, and Riley coos in response. Joy beams.)</i>\n</p>', '11': '<p><b>Joy:</b> <i>(narrates:)</i> It was amazing. Just Riley and me... Forever.\n</p>', '12': '<p><i>(Riley keeps giggling and Joy smiles in reply; suddenly, Riley starts crying, which confuses her.)</i>\n</p>', '13': '<p><b>Joy:</b> <i>(narrates:)</i> Er, for thirty three seconds.\n</p>', '14': '<p><i>(Next to Joy, a droopy and gloomy blue figure, Sadness, is working the button, which turns blue in response.)</i>\n</p>', '15': "<p><b>Sadness:</b> I'm Sadness.\n</p>", '16': "<p><b>Joy:</b> Oh, hello. I... I'm Joy. So... Can I just... If you could... I just want to fix that. Thanks.\n</p>", '17': '<p><i>(The two start arguing over the button as she speaks.)</i>\n</p>', '18': '<p><b>Joy:</b> <i>(narrates:)</i> And that was just the beginning. Headquarters only got more crowded from there.\n</p>', '19': '<p><i>(Riley, now a toddler, runs through the house pulling a wagon and giggling. In her mind, in the now formed Headquarters, Fear, a jagged purple figure, comes out from behind joy. The single button is now replaced with a control console.)</i>\n</p>', '20': '<p><b>Fear:</b> Very nice. Okay, looks like you got this. Very good.\n</p>', '21': "<p><i>(The screen shows everything through Riley's eyes, as she is running.)</i>\n</p>", '22': '<p><b>Fear:</b> Whoa, sharp turn! NO, LOOK OUT! NO!\n</p>', '23': '<p><i>(He takes action; the console turns purple in response.)</i>\n</p>', '24': "<p><b>Joy:</b> <i>(narrates:)</i> That's Fear. He's really good at keeping Riley safe.\n</p>", '25': "<p><i>(Fear's actions prompt Riley to stop running and notice the plugged cable, and step over it slowly.)</i>\n</p>", '26': "<p><b>Fear:</b> <i>(voiceover)</i> Easy, easy. AGH! OH MY! Oh, we're good. We're good.\n</p>", '27': '<p><i>(In Headquarters, the memories have been nestled on a shelf off to the left; a purple memory, indicating a fearful one, rolls in to nestle against the yellow one on the right.)</i>\n</p>', '28': '<p><b>Joy:</b> Whew!\n</p>', '29': '<p><b>Sadness:</b> Good job.\n</p>', '30': '<p><b>Fear:</b> Thank you. Thank you very much.\n</p>', '31': "<p><b>Joy:</b> And we're back!\n</p>", '32': '<p><i>(She takes over, prompting Riley to resume her silliness, knocking over a lamp in the process. Mr. Andersen picks her up.)</i>\n</p>', '33': '<p><b>Young Riley:</b> Oh!\n</p>', '34': '<p><i>(She is put in her high chair for lunch; she is served a bowl full of broccoli as Mr. Andersen ...

# %% [markdown]
# #### 1c

# %%
# To process the lines in the script, you need to do the following in chronological order:
#### Convert all characters to uppercase characters
#### Remove the following pieces of text: <P>, </P>, <B>, </B>, <I>, </I>
#### Remove all the unnecessary punctuation symbols denoted in the string below
unnecessary_punctuation = r"&$@[].,'#()-\"!?’_;:/"

# %%
removetext = ["<P>", "</P>", "<B>", "</B>", "<I>", "</I>"]
unnecessary_punctuation = r"&$@[].,'#()-\"!?’_;:/"

for key, value in jsondata.items():
    jsondata[key]= str(jsondata[key].upper())

for key2, value in jsondata.items():
    for i in range(0, len(removetext)):
        jsondata[key2]= jsondata[key2].replace(removetext[i],"")
for key3, value in jsondata.items():
    for j in range(0, len(unnecessary_punctuation)):
        jsondata[key3]= jsondata[key3].replace(unnecessary_punctuation[j]," ")

print(jsondata)
# Out:
# {'0': 'JOY   NARRATES   DO YOU EVER LOOK AT SOMEONE AND WONDER   WHAT IS GOING ON INSIDE THEIR HEAD   WELL  I KNOW     WELL  I KNOW RILEY S HEAD  \n', '1': ' FADES UP IN A WHITE SPACE  IN A HOSPITAL ROOM  MR  AND MRS  ANDERSEN ARE ADMIRING THEIR NEWBORN BABY RILEY  WHO WAKES UP AND COOS HAPPILY  ZOOM IN ON RILEY S HEAD  \n', '2': ' IN RILEY S MIND  EVERYTHING IS BLACK  FROM OUT OF THE DARKNESS STEPS A GLOWING FIGURE  JOY  SHE COMES FORWARD AND SEES A BLANK SCREEN ABOVE HER  BELOW HER IS A SINGLE BUTTON  SHE PRESSES IT  AND IT TURNS YELLOW LIKE HER  RILEY IS HEARD COOING  \n', '3': ' ZOOM BACK FROM JOY TO THE REAL WORLD  SHOWING THE BABY RILEY AS SHE COOS AND GIGGLES HAPPILY  \n', '4': 'JOY   NARRATES   AND THERE SHE WAS   \n', '5': ' ON THE SCREEN  MR  AND MRS  ANDERSENS  FACES MATERIALIZE INTO VIEW  \n', '6': 'MRS  ANDERSEN  HELLO  RILEY \n', '7': 'MR  ANDERSEN  OH  LOOK AT YOU  AREN T YOU A LITTLE BUNDLE OF JOY \n', '8': ' A DING IS HEARD  AND A GLOWING YELLOW ORB OF WHAT JUST HAPPENED IS FORMED FROM BEHIND THE SCREEN  JOY EXAMINES IT  \n', '9': 'MEMORY MR  ANDERSEN  AREN T YOU A LITTLE BUNDLE OF JOY \n', '10': ' SHE PUTS THE MEMORY BACK IN PLACE AND IT ROLLS ACROSS A RACK AROUND THE AREA  MAKING THE LIGHTS COME UP AND REVEALING A RED VIOLET SPACE OF GEARS  AS HEADQUARTERS IS STARTING TO FORM  JOY IS ASTOUNDED  SHE PRESSES THE BUTTON AGAIN  AND RILEY COOS IN RESPONSE  JOY BEAMS  \n', '11': 'JOY   NARRATES   IT WAS AMAZING  JUST RILEY AND ME    FOREVER \n', '12': ' RILEY KEEPS GIGGLING AND JOY SMILES IN REPLY  SUDDENLY  RILEY STARTS CRYING  WHICH CONFUSES HER  \n', '13': 'JOY   NARRATES   ER  FOR THIRTY THREE SECONDS \n', '14': ' NEXT TO JOY  A DROOPY AND GLOOMY BLUE FIGURE  SADNESS  IS WORKING THE BUTTON  WHICH TURNS BLUE IN RESPONSE  \n', '15': 'SADNESS  I M SADNESS \n', '16': 'JOY  OH  HELLO  I    I M JOY  SO    CAN I JUST    IF YOU COULD    I JUST WANT TO FIX THAT  THANKS \n', '17': ' THE TWO START ARGUING OVER THE BUTTON AS SHE SPEAKS  \n', '18': 'JOY   NARRATES   AND THAT WAS JUST THE BEGINNING  HEADQUARTERS ONLY GOT MORE CROWDED FROM THERE \n', '19': ' RILEY  NOW A TODDLER  RUNS THROUGH THE HOUSE PULLING A WAGON AND GIGGLING  IN HER MIND  IN THE NOW FORMED HEADQUARTERS  FEAR  A JAGGED PURPLE FIGURE  COMES OUT FROM BEHIND JOY  THE SINGLE BUTTON IS NOW REPLACED WITH A CONTROL CONSOLE  \n', '20': 'FEAR  VERY NICE  OKAY  LOOKS LIKE YOU GOT THIS  VERY GOOD \n', '21': ' THE SCREEN SHOWS EVERYTHING THROUGH RILEY S EYES  AS SHE IS RUNNING  \n', '22': 'FEAR  WHOA  SHARP TURN  NO  LOOK OUT  NO \n', '23': ' HE TAKES ACTION  THE CONSOLE TURNS PURPLE IN RESPONSE  \n', '24': 'JOY   NARRATES   THAT S FEAR  HE S REALLY GOOD AT KEEPING RILEY SAFE \n', '25': ' FEAR S ACTIONS PROMPT RILEY TO STOP RUNNING AND NOTICE THE PLUGGED CABLE  AND STEP OVER IT SLOWLY  \n', '26': 'FEAR   VOICEOVER  EASY  EASY  AGH  OH MY  OH  WE RE GOOD  WE RE GOOD \n', '27': ' IN HEADQUARTERS  THE MEMORIES HAVE BEEN NESTLED ON A SHELF OFF TO THE LEFT  A PURPLE MEMORY  INDICATING A FEARFUL ONE  ROLLS IN TO NESTLE AGAINST THE YELLOW ONE ON THE RIGHT  \n', '28': 'JOY  WHEW \n', '29': 'SADNESS  GOOD JOB \n', '30': 'FEAR  THANK YOU  THANK YOU VERY MUCH \n', '31': 'JOY  AND WE RE BACK \n', '32': ' SHE TAKES OVER  PROMPTING RILEY TO RESUME HER SILLINESS  KNOCKING OVER A LAMP IN THE PROCESS  MR  ANDERSEN PICKS HER UP  \n', '33': 'YOUNG RILEY  OH \n', '34': ' SHE IS PUT IN HER HIGH CHAIR FOR LUNCH  SHE IS SERVED A BOWL FULL OF BROCCOLI AS MR  ANDERSEN TRIES TO FEED HER A STALK  \n', '35': 'MR  ANDERSEN  HERE WE GO  ALL RIGHT  OPEN \n', '36': 'JOY  HMM  THIS LOOKS NEW \n', '37': 'FEAR  YOU THINK IT S SAFE \n', '38': 'SADNESS  WHAT IS IT \n', '39': ' ON THE SCREEN  MR  ANDERSEN BRINGS THE SPOONFUL FORWARD  HERE COMES A GREEN FEMININE FIGURE  DISGUST  WHO TAKES CONTROL  \n', '40': 'DISGUST  OKAY  CAUTION  THERE IS A DANGEROUS SMELL  PEOPLE  HOLD ON  WHAT IS THAT \n', '41': 'JOY   NARRATES   THIS IS DISGUST  SHE BASICALLY KEEPS RILEY FROM BEING POISONED  PHYSICALLY AND SOCIALL ...

# %% [markdown]
# #### 1d

# %%
# From here, create a dictionary called `wordcount_dictionary` that will have the key:value pair of word:count
# But, only include words that are three (3) letters or more

wordcount_dictionary = {
}
for key, value in jsondata.items():
    newlist = (jsondata.get(key)).split()
    for i in range(0,len(newlist)):
        if len(newlist[i])>=3:
            if newlist[i] in list(wordcount_dictionary.keys()):
Y': 1, 'ABOUT': 33, 'THINGS': 17, 'FAIR': 1, 'HOW': 30, 'PLAY': 20, 'OLD': 8, 'MAN': 6, 'SURE': 17, 'AFTER': 13, 'MANS': 1, 'LETTING': 2, 'FURIOUS': 1, 'YELL': 5, 'DOES': 9, 'THING': 8, 'HEAVY': 1, 'DRUMROLL': 1, 'BACKGROUND': 1, 'SCORE': 1, 'SCREAM': 5, 'ANGRY': 3, 'THROWING': 1, 'FIT': 3, 'WHEN': 23, 'INT ...
# 2489

# %%
# If there were no errors in the way you processed your data, 
# this should output "Looks Good!"  

import numpy as np
import pandas as pd 

df1 = pd.read_json("output_dictionary_Q1.json",typ="dictionary").sort_values()
df2 = pd.Series(wordcount_dictionary).sort_values()

assert df1.equals(df2), "The dictionaries are not equal. Please check your code again."

print("Looks Good!")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[124], line 10
#       7 df1 = pd.read_json("output_dictionary_Q1.json",typ="dictionary").sort_values()
#       8 df2 = pd.Series(wordcount_dictionary).sort_values()
# ---> 10 assert df1.equals(df2), "The dictionaries are not equal. Please check your code again."
#      12 print("Looks Good!")
#
# AssertionError: The dictionaries are not equal. Please check your code again.

# %% [markdown]
# #### 1e

# %%
# Afterwards, we want to convert that dictionary to a list containing tuples
# Create a list called "final_wordlist_of_tuples" containing tuples 
# Each tuple should be as follows: (word,count)
# Sort the list by `count` (the second element of the tuple) in descending order
# A correct sample is shown in the markdown cell below
# Hint: this can be done using lambda but you can use a regular function definition. 
# Make sure you go through the mini-tutorial at the start of this problem.

listed = list(wordcount_dictionary.items())
listed.sort(key=lambda x: x[1], reverse=True)

print(listed)
# Out:
# [('THE', 830), ('JOY', 585), ('AND', 351), ('RILEY', 326), ('SADNESS', 274), ('YOU', 273), ('SHE', 188), ('BONG', 171), ('BING', 170), ('THAT', 147), ('FEAR', 146), ('WHAT', 134), ('THIS', 133), ('HER', 132), ('ANGER', 116), ('MEMORY', 112), ('OUT', 106), ('DISGUST', 99), ('THEY', 90), ('ARE', 89), ('BACK', 84), ('HEADQUARTERS', 80), ('ANDERSEN', 77), ('THERE', 77), ('BUT', 71), ('JUST', 69), ('ALL', 66), ('GET', 66), ('DAD', 65), ('CAN', 64), ('MOM', 64), ('ISLAND', 63), ('INTO', 62), ('MEMORIES', 61), ('DOWN', 60), ('INT', 60), ('LIKE', 59), ('HERE', 59), ('NOT', 57), ('WITH', 56), ('WAS', 54), ('FOR', 53), ('HEY', 52), ('OFF', 49), ('YEAH', 49), ('CORE', 49), ('HAVE', 48), ('NOW', 47), ('OVER', 46), ('ONE', 46), ('KNOW', 45), ('FROM', 45), ('RIGHT', 44), ('DON', 43), ('LET', 41), ('LOOK', 40), ('WELL', 40), ('MRS', 40), ('NEW', 40), ('YOUR', 39), ('OKAY', 38), ('LOOKS', 38), ('GOOD', 38), ('CONT', 36), ('WAY', 36), ('GOING', 35), ('CONSOLE', 35), ('THEM', 35), ('TRAIN', 35), ('ROOM', 34), ('WHO', 34), ('WAIT', 34), ('HAPPY', 34), ('ABOUT', 33), ('THROUGH', 32), ('HOCKEY', 32), ('DAY', 32), ('OUR', 31), ('DID', 31), ('COME', 30), ('HOW', 30), ('MAKE', 30), ('SAN', 30), ('AWAY', 30), ('DREAM', 30), ('SCREEN', 29), ('AROUND', 29), ('FRANCISCO', 29), ('GREAT', 28), ('HOUSE', 27), ('HIS', 27), ('HIM', 27), ('GOT', 26), ('RUNS', 26), ('BEHIND', 25), ('TIME', 25), ('FAMILY', 25), ('TOWARDS', 25), ('TURNS', 24), ('BLUE', 23), ('WHEN', 23), ('FORGETTER', 23), ('NARRATES', 22), ('LONG', 22), ('STILL', 22), ('RUN', 22), ('WHERE', 21), ('WHICH', 20), ('PLAY', 20), ('EMOTIONS', 20), ('IDEA', 20), ('HEAD', 19), ('WANT', 19), ('HAS', 19), ('GUARD', 19), ('WILL', 19), ('WALKS', 19), ('SUBCONSCIOUS', 19), ('DOOR', 18), ('WINDOW', 18), ('COMES', 17), ('REALLY', 17), ('STOP', 17), ('LEFT', 17), ('GONNA', 17), ('THINGS', 17), ('SURE', 17), ('THEN', 17), ('GOES', 17), ('WOULD', 17), ('ANOTHER', 17), ('SOMETHING', 17), ('BEFORE', 17), ('PLACE', 16), ('AGAIN', 16), ('COULD', 16), ('GUYS', 16), ('GOOFBALL', 16), ('TUBE', 16), ('SORRY', 16), ('PIZZA', 16), ('SCHOOL', 16), ('THEIR', 15), ('TWO', 15), ('MORE', 15), ('WHOA', 15), ('TRIES', 15), ('THINK', 15), ('MAKES', 15), ('OUTSIDE', 15), ('TOO', 15), ('LOVE', 15), ('SEE', 15), ('HUH', 15), ('PULLS', 15), ('ROCKET', 15), ('WERE', 15), ('EVERYTHING', 14), ('FACE', 14), ('FRIEND', 14), ('MEG', 14), ('OTHER', 14), ('ALRIGHT', 14), ('GOTTA', 14), ('SAD', 14), ('TAKE', 14), ('MIND', 13), ('BUTTON', 13), ('NICE', 13), ('AFTER', 13), ('FLOOR', 13), ('CAR', 13), ('GETS', 13), ('FALLS', 13), ('STREET', 13), ('WALK', 13), ('WORK', 13), ('CLOUD', 13), ('PUTS', 12), ('VERY', 12), ('TAKES', 12), ('HOLD', 12), ('SHELVES', 12), ('EACH', 12), ('FRIENDSHIP', 12), ('IMAGINARY', 12), ('EXT', 12), ('COOL', 12), ('READ', 12), ('DOING', 12), ('TELL', 12), ('TEAM', 12), ('ONTO', 12), ('FEMALE', 12), ('GUM', 12), ('STATION', 12), ('BUS', 12), ('INSIDE', 11), ('ACROSS', 11), ('WORKING', 11), ('BEEN', 11), ('SIDE', 11), ('THESE', 11), ('BEST', 11), ('FRIENDS', 11), ('ISN', 11), ('WHY', 11), ('UNTIL', 11), ('REMEMBER', 11), ('TRY', 11), ('FUN', 11), ('TRYING', 11), ('SLEEP', 11), ('MINNESOTA', 11), ('MALE', 11), ('SATCHEL', 11), ('DIRECTOR', 11), ('CAMERA', 11), ('JANGLES', 11), ('STEPS', 10), ('SEES', 10), ('ROLLS', 10), ('SUDDENLY', 10), ('CRYING', 10), ('THREE', 10), ('TURN', 10), ('THANK', 10), ('PUT', 10), ('SITS', 10), ('SAY', 10), ('BIG', 10), ('PUSHES', 10), ('FIRST', 10), ('ICE', 10), ('LIGHT', 10), ('LAST', 10), ('LIVING', 10), ('FRONT', 10), ('DARK', 10), ('WATCHES', 10), ('CALL', 10), ('GIRL', 10), ('THOUGHT', 10), ('NOTHING', 10), ('PHONE', 10), ('GUESS', 10), ('WON', 10), ('EVEN', 10), ('SHOULD', 10), ('CHANGE', 10), ('DUMP', 10), ('WORKERS', 10), ('FIGURE', 9), ('FORWARD', 9), ('STARTS', 9), ('NEXT', 9), ('FIX', 9), ('EYES', 9), ('RUNNING', 9), ('DOES', 9), ('PRETTY', 9), ('STANDS', 9), ('JUMPS', 9), ('EVERYONE', 9), ('PART', 9), ('NIGHT', 9), ('TERM', 9), ('TODAY', 9), ('MOVING', 9), ('HAD', 9), ('MADE', 9), ( ...

# %% [markdown]
# ___<div align="center">Once sorted, this should be the output of the first five items.</div>___
#
# |         |             |
# |:--------|------------:|
# | THE     |         830 |
# | JOY     |         585 |
# | AND     |         351 |
# | RILEY   |         326 |
# | SADNESS |         274 |

# %% [markdown]
# # Question 2: Wait... What is LP Doing Here?
# I swear you don't need to do LP here. In fact, the LP formulation is already shown below!

# %% [markdown]
# #### LP Problem
# In the realm of Sanctoria, nestled deep within the misty forests and craggy mountains, lies the legendary dungeon of The Lost King. It is said to be filled with untold riches, ancient relics, and formidable monsters guarding its treasures. As the wise and benevolent ruler of Sanctoria, King Hexter has decided to assemble a daring raiding party to plunder the depths of the dungeon and reclaim its treasures for the kingdom.
#
# As the illustrious ruler of Sanctoria, King Hexter is faced with the daunting task of assembling a formidable dungeon raiding party. The success of the raid hinges upon the careful selection and allocation of resources to hire Fighters, Rangers, and Clerics for the expedition into the depths of the Lost King’s home.
#
# In the planning of this dungeon raid, the King’s advisors have provided him with the following: Gold: The kingdom's treasury can afford to spend no more than 18000 gold coins on hiring adventurers. Each Fighter costs 1000 gold coins, each Ranger costs 600 gold coins, and each Cleric costs 750 gold coins. Lumber: The construction of necessary equipment for each troop requires ample quality lumber. The kingdom has 12000 units of lumber available for the raid. Each Fighter requires 500 units, each Ranger requires 750 units, and each Cleric requires 300 units. Food: The raid will last several weeks so food must be kept and stored during the raid. The raid will be able to carry 1500 units of food available for the raid. Each Fighter requires 50 units, each Ranger requires 45 units, and each Cleric requires 75 units. Power: The power of the raiding party will dictate the level of the raid’s success. Each Fighter gives 10 points, each Ranger gives 12 points, each Cleric gives 16 points.
#
# The King’s military advisors have also discussed strategies that will be employed in the raid: Having more Fighters than Rangers will bolster the raiding party's frontline defense To avoid casualties, each Cleric must have at most 3 Fighters that they are supporting

# %% [markdown]
# # LP Formulation
#
# **Decision Variables:**
# - (F): Number of Fighters
# - (R): Number of Rangers
# - (C): Number of Clerics
#
# **Objective:** Maximize the power of the raiding party.
#
# $$ \text{Maximize Z:  } 10F + 12R + 16C $$
#
#
# **Subject to:**
#
# \begin{aligned}
# 1000F + 600R + 750C &\leq 18000 && \text{(Gold constraint)} \\
# 500F + 750R + 300C &\leq 12000 && \text{(Lumber constraint)} \\
# 50F + 45R + 75C &\leq 1500 && \text{(Food constraint)} \\
# F, R, C &\geq 0 && \text{(Non-negativity constraints)}
# \end{aligned}

# %%
# With the LP Formulation as a basis, find the optimal solution to the problem using Python
# Use the variable `optimal_Z` to store the value of the Maximum Z
# Use the variables `optimal_F`, `optimal_R`, and `optimal_C` to store 
# the optimal solution of Fighters, Rangers, and Clerics respectively
# Note: There may be multiple configurations of F, R, C to attain the Maximum Z. 
# Hint: Don't use your DecSci brain, use your Python programming brain

optimal_Z = 0
optimal_F= 0
optimal_C = 0
optimal_R =0

while (1000*optimal_F +600*optimal_R + 750*optimal_C <=18000) and (500*optimal_F +750*optimal_R +300* optimal_C <=12000) and (50* optimal_F + 45*optimal_R + 75* optimal_C<=1500):
    optimal_C +=1
    optimal_R+=1
    optimal_F+=1
   
    
    

optimal_Z = 10*optimal_F +12*optimal_R + 16*optimal_C

print (optimal_Z)
# Out:
# 304

# %%
# If there were no errors in the way you processed your data, 
# this should output "Looks Good!"  

assert optimal_Z == 322
assert (1000*optimal_F + 600*optimal_R + 750*optimal_C) <= 18000
assert (500*optimal_F + 750*optimal_R + 300*optimal_C) <= 12000
assert (50*optimal_F + 45*optimal_R + 75*optimal_C) <= 1500
print("Looks Good!")

# %% [markdown]
# # Question 3: Collatz

# %% [markdown]
# #### 3a

# %% [markdown]
# The __Collatz Conjecture__ is a mathematical sequence defined as follows:
#
# 1. Start with any positive integer n.
# 2. If n is even, divide it by 2 to get n / 2.
# 3. If n is odd, multiply it by 3 and add 1 to get 3n + 1.
# 4. Repeat the process with the resulting number.
# 5. The conjecture states that no matter which positive integer you start with, you will always eventually reach 1.

# %% [markdown]
# As an example, the number 5 will follow this sequence:
# - Start at __`5`__
# - 5 is odd, so we multiply by 3 and adds 1 to get __`16`__
# - 16 is even, so we divide by 2 to get __`8`__
# - 8 is even, so we divide by 2 to get __`4`__
# - 4 is even, so we divide by 2 to get __`2`__
# - 2 is even, so we divide by 2 to get __`1`__
# - Since the number is 1, we stop the sequence.
#
# For the purposes of this problem, let's call the list containing the numbers __[5, 16, 8, 4, 2, 1]__ the __`Collatz Sequence`__.
#
# This sequence also has a __`Collatz Length`__ of 6, since the sequence cycled through 6 numbers.
#
# The sequence also had a __`Max Collatz`__ of 16, since that was the highest number in the sequence.
#
# Lastly, the sequence had a __`Sequence Sum`__ of 36, since that is the sum of all the numbers in the sequence.

# %%
def Collatz(start_number):
    
    '''
    Create a SINGLE FUNCTION that will return the
    `Collatz Sequence`, the `Collatz Length`,
    and the `Max Collatz` in a dictionary.

    The key-value pairs will be the following:
    "collatz_sequence": the list containing the numbers of the sequence
    "collatz_length": the length of the sequence
    "max_collatz": the maximum number achieved in the sequence
    "sequence_sum": the sum of all the numbers in the sequence 

    Parameters
    ----------
    start_number: int
        the number used to start the sequence

    Returns
    -------
    dictionary
        the dictionary containing the key-value pairs of the
        collatz_sequence, collatz_length, max_collatz, and sequence_sum
    '''
    collatzstuff ={
        }

    collatz_sequence=[]
    collatz_length=0
    max_collatz=0
    sequence_sum=0
    while start_number!=1:
        if start_number %2==0:
            start_number = start_number/2
            collatz_sequence.append(int(start_number))
        else:
            start_number= (start_number*3)+1
            collatz_sequence.append(int(start_number))
    collatzstuff["collatz_sequence"] = collatz_sequence
    for i in range(0, len(collatz_sequence)):
        if max_collatz <=collatz_sequence[i]:
            max_collatz = collatz_sequence[i]

    collatzstuff["max_collatz"] = max_collatz
    collatzstuff["collatz_length"] = len(collatz_sequence)



    collatz_length= len(collatz_sequence)
    for j in range(0, len(collatz_sequence)):
        sequence_sum += collatz_sequence[j]
    collatzstuff["sequence_sum"] = sequence_sum
            
    return (collatzstuff)
print(Collatz(10))
# Out:
# {'collatz_sequence': [5, 16, 8, 4, 2, 1], 'max_collatz': 16, 'collatz_length': 6, 'sequence_sum': 36}

# %% [markdown]
# #### 3b

# %%
def Collatz_winner(number_list):
    '''
    Given a list of positive integers, return the `winner`
    among them. The `winner` is categorized as such:
        
        1. The number has the largest `collatz_length`; and
        2. The number has the largest `max_collatz`

    If there is no winner, then the function must return None

    Parameters
    ----------
    number_list: list
        a list of positive integers

    Returns
    -------
    integer (or NoneType)
        the "winner" that follows the specific criteria above
        returns a None if it does not meet all the criteria above
    '''
    final = ""
    lenlist =[]
    maxlen = 0
    leni =0
    maxlist =[]
    maxmax =0
    maxi=0
    for i in range (0, len(number_list)):
        collatz_sequence = []
        max_collatz =0
        start_number = number_list[i]
        while start_number!=1:
            if start_number %2==0:
                start_number = start_number/2
                collatz_sequence.append(int(start_number))
            else:
                start_number= (start_number*3)+1

        for j in range(0, len(collatz_sequence)):
            if max_collatz <=collatz_sequence[i]:
                max_collatz = collatz_sequence[i]
            
        lenlist.append(len(collatz_sequence))
        maxlist.append(max_collatz)
    for k in range(0, len(lenlist)):
        if lenlist[k] >=maxlen:
            maxlen = lenlist[k]
            leni = k
        if maxlist[k] >= maxmax:
            maxmax = maxlen
            maxi = k 


    if leni == maxi :
        final = number_list[maxi]
    else:
        final = "None"
            
    
        
    return final
        
        
Collatz_winner([1,10])
# Out:
# 10

# %%
assert Collatz_winner(range(1,51)) == 27
assert Collatz_winner(range(1,10)) == 9
assert Collatz_winner(range(50,100)) == 97
assert Collatz_winner(range(50,100,4)) == 54
assert Collatz_winner(range(20,131,5)) == 110
assert Collatz_winner(range(75,180,9)) == 129
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[307], line 1
# ----> 1 assert Collatz_winner(range(1,51)) == 27
#       2 assert Collatz_winner(range(1,10)) == 9
#       3 assert Collatz_winner(range(50,100)) == 97
#
# Cell In[305], line 41, in Collatz_winner(number_list)
#      38         start_number= (start_number*3)+1
#      40 for j in range(0, len(collatz_sequence)):
# ---> 41     if max_collatz <=collatz_sequence[i]:
#      42         max_collatz = collatz_sequence[i]
#      44 lenlist.append(len(collatz_sequence))
#
# IndexError: list index out of range
